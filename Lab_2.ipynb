# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#parameters
frequency = 2400 #MHz (2.4 GHz WiFi)
distances = np.linspace(0.1, 20, 100) #km

# %%
#plot
plt.figure(figsize=(8,5))
plt.plot(distances, fspl, label="The magic line of FSPL at 2.4 GHz")
plt.xlabel("Distance (what is a kilometer?)")
plt.ylabel("Path Loss (dB)")
plt.title("Free-Space Path Loss vs Distance")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2650490507.py in <cell line: 0>()
#       1 #plot
#       2 plt.figure(figsize=(8,5))
# ----> 3 plt.plot(distances, fspl, label="The magic line of FSPL at 2.4 GHz")
#       4 plt.xlabel("Distance (what is a kilometer?)")
#       5 plt.ylabel("Path Loss (dB)")
#
# NameError: name 'fspl' is not defined

# %%
#plot
# Calculate Free-Space Path Loss (FSPL)
fspl = 32.45 + 20 * np.log10(frequency) + 20 * np.log10(distances)
plt.figure(figsize=(8,5))
plt.plot(distances, fspl, label="The magic line of FSPL at 2.4 GHz")
plt.xlabel("Distance (what is a kilometer?)")
plt.ylabel("Path Loss (dB)")
plt.title("Free-Space Path Loss vs Distance")
plt.grid(True)
plt.legend()
plt.show()
